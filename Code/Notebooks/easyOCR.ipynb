# %% [markdown]
# ## Kernel: PyTorch
#
#  - Create DataFrame that contains image name and a list of all words found with easyOCR

# %%
import easyocr
import os
import pandas as pd
from PIL import Image
import numpy as np
import time
import spacy
from spacy_langdetect import LanguageDetector

import de_core_news_sm
import en_core_web_sm

from langdetect import detect, DetectorFactory
DetectorFactory.seed = 0

import torch
torch.cuda.is_available()
# Out:
# True

# %%
df = pd.DataFrame(columns=["Path", "Words"])

reader = easyocr.Reader(['en', 'de'], gpu=True) 

PATH = "../../Data/PlakateBayreuth"
ROTATIONS = [0, 90, 180, 270]

# %%
func = np.vectorize(lambda t: len(t) > 2)

def find_most_likely_words_array(all_words):
    all_words_len = [0, 0, 0, 0]
    
    for i, words in enumerate(all_words):
        
        try:
            long_words = np.array(words)[func(words)]
        except:
            long_words = np.array([])
        
        try:
            for word in long_words:
                try:
                    word = word.strip()
                    lan = detect(word)
                    if lan == "de" or lan == "en" or lan == "fr":
                        all_words_len[i] += 1
                except:
                    pass
        except:
            pass
        
    return np.argmax(all_words_len)

# %%
all_paths = []

for name in os.listdir(PATH):
    file_path = os.path.join(PATH, name)
    all_paths.append(file_path)

# %%
all_paths = all_paths
print(len(all_paths))
# Out:
# 17540

# %%
start_time = time.time() 

for i, name in enumerate(all_paths):        
    file_path = os.path.join(PATH, name)
    all_words = []
    
    for angle in ROTATIONS:
        im = Image.open(file_path)
        out = im.rotate(angle)
        out.save(file_path)
    
        result = reader.readtext(file_path)
        words = [r[1] for r in result]
        all_words.append(words)
    
    index = find_most_likely_words_array(all_words)
    
    df = df.append({"Path": file_path,
                    "Words_0": all_words[0],
                    "Words_90": all_words[1],
                    "Words_180": all_words[2],
                    "Words_270": all_words[3],
                    "Most_Likely": all_words[index]}, ignore_index=True)
     
    if i % 500 == 0:
        elapsed_time = time.time() - start_time
        strf_time = time.strftime("%H:%M:%S", time.gmtime(elapsed_time))
        print(f"[{i}/{len(all_paths)}] Processed - Duration: {strf_time}")
# Out:
# [0/17540] Processed - Duration: 00:00:03
# [500/17540] Processed - Duration: 00:37:32
# [1000/17540] Processed - Duration: 01:21:17
# [1500/17540] Processed - Duration: 01:57:05
# [2000/17540] Processed - Duration: 02:26:10
# [2500/17540] Processed - Duration: 02:57:33
# [3000/17540] Processed - Duration: 03:32:39
# [3500/17540] Processed - Duration: 04:08:38
# [4000/17540] Processed - Duration: 04:53:41
# [4500/17540] Processed - Duration: 05:36:12
# [5000/17540] Processed - Duration: 06:13:48
# [5500/17540] Processed - Duration: 06:46:11
# [6000/17540] Processed - Duration: 07:22:10
# [6500/17540] Processed - Duration: 07:55:33
# [7000/17540] Processed - Duration: 08:32:41
# [7500/17540] Processed - Duration: 09:01:58
# [8000/17540] Processed - Duration: 09:32:02
# [8500/17540] Processed - Duration: 10:04:16
# [9000/17540] Processed - Duration: 10:33:38
# [9500/17540] Processed - Duration: 11:07:24
# [10000/17540] Processed - Duration: 11:40:35
# [10500/17540] Processed - Duration: 12:09:03
# [11000/17540] Processed - Duration: 12:37:21
# [11500/17540] Processed - Duration: 13:03:19
# [12000/17540] Processed - Duration: 13:30:40
# [12500/17540] Processed - Duration: 14:05:49
# [13000/17540] Processed - Duration: 14:36:31
# [13500/17540] Processed - Duration: 14:58:40
# [14000/17540] Processed - Duration: 15:34:13
# [14500/17540] Processed - Duration: 16:10:29
# [15000/17540] Processed - Duration: 16:45:16
# [15500/17540] Processed - Duration: 17:14:30
# [16000/17540] Processed - Duration: 17:49:55
# [16500/17540] Processed - Duration: 18:22:29
# [17000/17540] Processed - Duration: 18:55:47
# [17500/17540] Processed - Duration: 19:34:09

# %%
df.to_csv("poster_text.csv", encoding='utf-8', index=False)

# %%
df.head()
# Out:
#                                                 Path Words  \
# 0  ../../Data/PlakateBayreuth/../../Data/PlakateB...   NaN
# 1  ../../Data/PlakateBayreuth/../../Data/PlakateB...   NaN
# 2  ../../Data/PlakateBayreuth/../../Data/PlakateB...   NaN
# 3  ../../Data/PlakateBayreuth/../../Data/PlakateB...   NaN
# 4  ../../Data/PlakateBayreuth/../../Data/PlakateB...   NaN
#
#                                          Most_Likely  \
# 0  [FORUM, Kirchner, Das, expressionistische Expe...
# 1  [SEST, I4, g,  ' ^ ., 1472, Das Pa on Daumier,...
# 2  [U, M 1 V R (; E R, KUNSTHALLE, LICHTWARK, REV...
# 3  [PRIS O NS, AUSSTELLUNGE, DER FRIEDRICH-SCHLLE...
# 4  [Christoph Brech, it's about time, 10 Mai, 14 ...
#
#                                              Words_0  \
# 0  [0, adhvie irquur? Ma SchnrerrfrWnrm (orluin, ...
# 1               [K0, 0, (, 8, 3, 4, 4, 91, 2,  `, 3]
# 2                        [4, 2, 2, 2, ~, 5, ~, 1, =]
# 3               [3, 5, 2, I, 9, 7, 2, ~, 1, 1, 5, 9]
# 4             [8g, ;, 3, 1, ", 9, 98, 6, 9, 2, 8, 1]
#
#                                            Words_180  \
# 0  [SmnquH 7qeusneqJeY, vI0Z '6'4  '$*62, JUMUI3d...
# 1  [SEST, I4, g,  ' ^ ., 1472, Das Pa on Daumier,...
# 2  [U, M 1 V R (; E R, KUNSTHALLE, LICHTWARK, REV...
# 3  [g, Aunau, +lo7 I7nf ` Z7e & IVW '0 1, VNJC LV...
# 4  [Christoph Brech, it's about time, 10 Mai, 14 ...
#
#                                            Words_270  \
# 0  [], 1, |, p, o;, 4, |, &, TAdfse '777haat) env...
# 1                       [3, 9, ~a, 5, 5, 7, p, K, 5]
# 2                                 [=, 1, 2, [, =, 0]
# 3              [2, %, p, 1, , 2, ~, 8a, I/, =, 5, 2]
# 4    [1, 5, 6, 3, 6, 85, 2, 1, 4, 5, g, 8, g, 8g, []
#
#                                             Words_90
# 0  [FORUM, Kirchner, Das, expressionistische Expe...
# 1  [anneTesnos, pun, Iowumnpd, UOAe  sea, ss, ' '...
# 2  [aaLISIAH&, XdVMLH)I7, FTIVHLSNNY, M a ') M .1...
# 3  [PRIS O NS, AUSSTELLUNGE, DER FRIEDRICH-SCHLLE...
# 4  [qu uoqejedooy ui, a4o1xsIuUF vor "IS pun, Suo...

# %%
df.shape
# Out:
# (17786, 7)

# %%
df2 = pd.read_csv("poster_text.csv")

# %%
df2.shape
# Out:
# (17786, 7)

# %%
df2.head()
# Out:
#                                                 Path  Words  \
# 0  ../../Data/PlakateBayreuth/../../Data/PlakateB...    NaN
# 1  ../../Data/PlakateBayreuth/../../Data/PlakateB...    NaN
# 2  ../../Data/PlakateBayreuth/../../Data/PlakateB...    NaN
# 3  ../../Data/PlakateBayreuth/../../Data/PlakateB...    NaN
# 4  ../../Data/PlakateBayreuth/../../Data/PlakateB...    NaN
#
#                                          Most_Likely  \
# 0  ['FORUM', 'Kirchner', 'Das', 'expressionistisc...
# 1  ['SEST', 'I4', 'g', " ' ^ .", '1472', 'Das Pa ...
# 2  ['U', 'M 1 V R (; E R', 'KUNSTHALLE', 'LICHTWA...
# 3  ['PRIS O NS', 'AUSSTELLUNGE', 'DER FRIEDRICH-S...
# 4  ['Christoph Brech', "it's about time", '10 Mai...
#
#                                              Words_0  \
# 0  ['0', 'adhvie irquur? Ma SchnrerrfrWnrm (orlui...
# 1  ['K0', '0', '(', '8', '3', '4', '4', '91', '2'...
# 2      ['4', '2', '2', '2', '~', '5', '~', '1', '=']
# 3  ['3', '5', '2', 'I', '9', '7', '2', '~', '1', ...
# 4  ['8g', ';', '3', '1', '"', '9', '98', '6', '9'...
#
#                                            Words_180  \
# 0  ['SmnquH 7qeusneqJeY', "vI0Z '6'4  '$*62", 'JU...
# 1  ['SEST', 'I4', 'g', " ' ^ .", '1472', 'Das Pa ...
# 2  ['U', 'M 1 V R (; E R', 'KUNSTHALLE', 'LICHTWA...
# 3  ['g', 'Aunau', "+lo7 I7nf ` Z7e & IVW '0 1", '...
# 4  ['Christoph Brech', "it's about time", '10 Mai...
#
#                                            Words_270  \
# 0  [']', '1', '|', 'p', 'o;', '4', '|', '&', "TAd...
# 1     ['3', '9', '~a', '5', '5', '7', 'p', 'K', '5']
# 2                     ['=', '1', '2', '[', '=', '0']
# 3  ['2', '%', 'p', '1', '', '2', '~', '8a', 'I/',...
# 4  ['1', '5', '6', '3', '6', '85', '2', '1', '4',...
#
#                                             Words_90
# 0  ['FORUM', 'Kirchner', 'Das', 'expressionistisc...
# 1  ['anneTesnos', 'pun', 'Iowumnpd', 'UOAe  sea',...
# 2  ['aaLISIAH&', 'XdVMLH)I7', 'FTIVHLSNNY', "M a ...
# 3  ['PRIS O NS', 'AUSSTELLUNGE', 'DER FRIEDRICH-S...
# 4  ['qu uoqejedooy ui', 'a4o1xsIuUF vor "IS pun',...

# %%
df2
# Out:
#                                                     Path  Words  \
# 0      ../../Data/PlakateBayreuth/../../Data/PlakateB...    NaN
# 1      ../../Data/PlakateBayreuth/../../Data/PlakateB...    NaN
# 2      ../../Data/PlakateBayreuth/../../Data/PlakateB...    NaN
# 3      ../../Data/PlakateBayreuth/../../Data/PlakateB...    NaN
# 4      ../../Data/PlakateBayreuth/../../Data/PlakateB...    NaN
# ...                                                  ...    ...
# 17781  ../../Data/PlakateBayreuth/../../Data/PlakateB...    NaN
# 17782  ../../Data/PlakateBayreuth/../../Data/PlakateB...    NaN
# 17783  ../../Data/PlakateBayreuth/../../Data/PlakateB...    NaN
# 17784  ../../Data/PlakateBayreuth/../../Data/PlakateB...    NaN
# 17785  ../../Data/PlakateBayreuth/../../Data/PlakateB...    NaN
#
#                                              Most_Likely  \
# 0      ['FORUM', 'Kirchner', 'Das', 'expressionistisc...
# 1      ['SEST', 'I4', 'g', " ' ^ .", '1472', 'Das Pa ...
# 2      ['U', 'M 1 V R (; E R', 'KUNSTHALLE', 'LICHTWA...
# 3      ['PRIS O NS', 'AUSSTELLUNGE', 'DER FRIEDRICH-S...
# 4      ['Christoph Brech', "it's about time", '10 Mai...
# ...                                                  ...
# 17781  ['MIKE', 'BIDLO', '<NOT WARHOL>', '0', '24', '...
# 17782  ['GH0w PALASTI', 'von und mit', 'Dieter Thomas...
# 17783  ['Ein neuer deutscherAbenteuer-Farbfilm', 'mit...
# 17784  ['Jiu', 'u', '72', '79 8U 81', '89 9/0 91', 'J...
# 17785  ['#', '1', 'Farbkarte #13', 'Big', '8ije', 'cu...
#
#                                                  Words_0  \
# 0      ['0', 'adhvie irquur? Ma SchnrerrfrWnrm (orlui...
# 1      ['K0', '0', '(', '8', '3', '4', '4', '91', '2'...
# 2          ['4', '2', '2', '2', '~', '5', '~', '1', '=']
# 3      ['3', '5', '2', 'I', '9', '7', '2', '~', '1', ...
# 4      ['8g', ';', '3', '1', '"', '9', '98', '6', '9'...
# ...                                                  ...
# 17781  ['MIKE', 'BIDLO', '<NOT WARHOL>', '0', '24', '...
# 17782  ['GH0w PALASTI', 'von und mit', 'Dieter Thomas...
# 17783  ['Ein neuer deutscherAbenteuer-Farbfilm', 'mit...
# 17784  ['Jiu', 'u', '72', '79 8U 81', '89 9/0 91', 'J...
# 17785  ['#', '1', 'Farbkarte #13', 'Big', '8ije', 'cu...
#
#                                                Words_180  \
# 0      ['SmnquH 7qeusneqJeY', "vI0Z '6'4  '$*62", 'JU...
# 1      ['SEST', 'I4', 'g', " ' ^ .", '1472', 'Das Pa ...
# 2      ['U', 'M 1 V R (; E R', 'KUNSTHALLE', 'LICHTWA...
# 3      ['g', 'Aunau', "+lo7 I7nf ` Z7e & IVW '0 1", '...
# 4      ['Christoph Brech', "it's about time", '10 Mai...
# ...                                                  ...
# 17781  ['Grauskala #13', 'M', 'BIG.', '28', '=', '~',...
# 17782  ['Grauskala #13', 'M', 'Big.', '5', ';', ' ', ...
# 17783  ['Grauskala #13', 'M', 'BIg.', '8 5', 'H', '5'...
# 17784  ['[', '1', '2', '5', '1', '1', '7', '1', '2', ...
# 17785  ['Grauskala #13', 'M', 'BIG.', '06 68', '1', '...
#
#                                                Words_270  \
# 0      [']', '1', '|', 'p', 'o;', '4', '|', '&', "TAd...
# 1         ['3', '9', '~a', '5', '5', '7', 'p', 'K', '5']
# 2                         ['=', '1', '2', '[', '=', '0']
# 3      ['2', '%', 'p', '1', '', '2', '~', '8a', 'I/',...
# 4      ['1', '5', '6', '3', '6', '85', '2', '1', '4',...
# ...                                                  ...
# 17781  ['HDIJOZ', '67 IvnOLn', "S66l II*8L -'vl", '43...
# 17782  ['J7Z@', '"1SS8q ueu }491S Ua}aMZ wap }W', '08...
# 17783  ['sni €', '"98"41nf9199', 'q1@H21 w! uouynpoud...
# 17784  ['Grauskala #13', 'M', 'BIG', 'Suh1oua_Syoh)in...
# 17785  ['8', '#', '0', '4340241-42/l443S', 'HP{S23M',...
#
#                                                 Words_90
# 0      ['FORUM', 'Kirchner', 'Das', 'expressionistisc...
# 1      ['anneTesnos', 'pun', 'Iowumnpd', 'UOAe  sea',...
# 2      ['aaLISIAH&', 'XdVMLH)I7', 'FTIVHLSNNY', "M a ...
# 3      ['PRIS O NS', 'AUSSTELLUNGE', 'DER FRIEDRICH-S...
# 4      ['qu uoqejedooy ui', 'a4o1xsIuUF vor "IS pun',...
# ...                                                  ...
# 17781  ['69 /iu', '79 8UU 81', '82   83', '84   85', ...
# 17782  ['79 860 81', '89*9091', '#', '8', ';', '1', '...
# 17783  ['8GU 81', '85   86', '910 91', '9', 'Hh', 'H'...
# 17784  ['2', '11', '1', '94 7', '1', '6', '2', '2', '...
# 17785  ['8GU 81', '90 91', 'Iuulmlouulua', 'WN', '9t8...
#
# [17786 rows x 7 columns]
